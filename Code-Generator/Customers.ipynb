# %%
import pandas as pd

# %%
pip install Faker
# Out:
# ...
#      |████████████████████████████████| 1.2MB 22.6MB/s
# ...

# %%
from faker import Faker
fake = Faker()

# %%
import random

# %%
customers = pd.read_csv("/content/drive/MyDrive/FP-MBD/database/customers2.csv")

# %%
customers.head()
# Out:
#   customer_id  ...             fax
# 0       ALFKI  ...     030-0076545
# 1       ANATR  ...    (5) 555-3745
# 2       ANTON  ...             NaN
# 3       AROUT  ...  (171) 555-6750
# 4       BERGS  ...   0921-12 34 67
#
# [5 rows x 11 columns]

# %%
len(customers['customer_id'].unique())
# Out:
# 91

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    91 non-null     object
#  1   company_name   91 non-null     object
#  2   contact_name   91 non-null     object
#  3   contact_title  91 non-null     object
#  4   address        91 non-null     object
#  5   city           91 non-null     object
#  6   region         31 non-null     object
#  7   postal_code    90 non-null     object
#  8   country        91 non-null     object
#  9   phone          91 non-null     object
#  10  fax            69 non-null     object
# dtypes: object(11)
# memory usage: 7.9+ KB

# %%
customers.tail()
# Out:
#    customer_id            company_name  ...           phone             fax
# 86       WARTH          Wartian Herkku  ...      981-443655      981-443655
# 87       WELLI  Wellington Importadora  ...   (14) 555-8122             NaN
# 88       WHITC    White Clover Markets  ...  (206) 555-4112  (206) 555-4115
# 89       WILMK             Wilman Kala  ...     90-224 8858     90-224 8858
# 90       WOLZA          Wolski  Zajazd  ...   (26) 642-7012   (26) 642-7012
#
# [5 rows x 11 columns]

# %%
cust_title_list = list(customers.contact_title.unique())
cust_title_list
# Out:
# ['Sales Representative',
#  'Owner',
#  'Order Administrator',
#  'Marketing Manager',
#  'Accounting Manager',
#  'Sales Agent',
#  'Sales Associate',
#  'Sales Manager',
#  'Marketing Assistant',
#  'Assistant Sales Agent',
#  'Assistant Sales Representative',
#  'Owner/Marketing Assistant']

# %%
reg_list_nan = list(customers.region.unique())
reg_list = ['BC',
 'SP',
 'OR',
 'DF',
 'RJ',
 'Táchira',
 'Co. Cork',
 'Isle of Wight',
 'WA',
 'CA',
 'Lara',
 'Nueva Esparta',
 'Québec',
 'AK',
 'NM',
 'ID',
 'WY',
 'MT']
reg_list
# Out:
# ['BC',
#  'SP',
#  'OR',
#  'DF',
#  'RJ',
#  'Táchira',
#  'Co. Cork',
#  'Isle of Wight',
#  'WA',
#  'CA',
#  'Lara',
#  'Nueva Esparta',
#  'Québec',
#  'AK',
#  'NM',
#  'ID',
#  'WY',
#  'MT']

# %%
import string

# %% [markdown]
# 4x data master = 4x91 = 364

# %%
def cust_id(nama):
  for i in range(len(nama)):
    if nama[i] == " ":
      spasi = i
      # increment = random.choice(range(1, 4))
      a = nama[i+1]
      break

  if i == 2:
    id = nama[:i].upper() + nama[3:6].upper()
  if i == 3:
    id = nama[:i].upper() + nama[4:6].upper()
  else:
    id = nama[:4].upper() + a.upper()
  return id

# %%
tes = 'Joe Jonas'
cust_id(tes)
# Out:
# 'JOEJO'

# %%
def cus_new(nama):
  hrf = random.choice(range(0, 5))
  temp = random.choice(string.ascii_letters).upper()
  nama = nama[:hrf] + temp + nama[hrf + 1:]
  return nama

# %%
# customer_ids = []
# customer_ids = list(set(customers['customer_id']))

# %%
def gen_id(id):
  angka = id
  kata = ""
  for i in range(0, 5):
    mod = angka%26
    kata = chr(65 + mod) + kata
    angka = int(angka/26)
  return kata

# %%
customer_id = []
company_name = []
contact_name = []
contact_title = []
address = []
city = []
region = []
postal_code = []
country = []
phone = []
fax = []

for i in range(0, 400000):
  company_name.append(fake.company())
  nama = fake.name()
  customer_idt = gen_id(i)
  # while(True):
  #   if (customer_idt in customer_ids):
  #     customer_idt = cus_new(customer_idt)
  #   else:
  #     break
  customer_id.append(customer_idt)
  # customer_ids.append(customer_idt)
  contact_name.append(nama)
  contact_title.append(random.choice(cust_title_list))

  address_fake = fake
  address.append(address_fake.address())
  city.append(address_fake.city())
  region.append(random.choice(reg_list))
  postal_code.append(address_fake.postcode())
  country.append(address_fake.country())

  ph_fx = fake.phone_number()
  phone.append(ph_fx)
  fax.append(ph_fx)

# %%
# customer_ids[:2]

# %%
len(customer_id)
# Out:
# 400000

# %%
temp = 400000
cus_prev = list(set(customers['customer_id']))
for x in range(0, 400000):
  if (customer_id[x] in cus_prev):
    print(customer_id[x])
    temp += 1
    customer_id[x] = gen_id(temp)
# Out:
# ALFKI
# ANATR
# ANTON
# AROUT

# %%
for x in range(0, 400000):
  if (customer_id[x] in cus_prev):
    print(customer_id[x])

# %%
df = pd.DataFrame(index=range(0, 400000))

# %%
df['customer_id'] = customer_id
df['company_name'] = company_name
df['contact_name'] = contact_name
df['contact_title'] = contact_title
df['address'] = address
df['city'] = city
df['region'] = region
df['postal_code'] = postal_code
df['country'] = country
df['phone'] = phone
df['fax'] = fax
df.head()
# Out:
#   customer_id  ...                   fax
# 0       AAAAA  ...     258-816-3387x0913
# 1       AAAAB  ...         (120)353-9835
# 2       AAAAC  ...  +1-715-765-2176x1713
# 3       AAAAD  ...          126.532.7823
# 4       AAAAE  ...   (614)135-4745x14925
#
# [5 rows x 11 columns]

# %%
len(df['customer_id'])
# Out:
# 400000

# %%
len(df['customer_id'].unique())
# Out:
# 400000

# %%
df['customer_id'].value_counts()
# Out:
# ARNKQ    1
# AINYM    1
# ARSET    1
# ADCBH    1
# AMZMK    1
#         ..
# AIZWY    1
# AURHH    1
# AVQUV    1
# AHIOE    1
# AJMOX    1
# Name: customer_id, Length: 400000, dtype: int64

# %%
df.to_csv("/content/drive/MyDrive/FP-MBD/Hasil-FIX/hasil-customer.csv", index=False)

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
hasil = pd.read_csv("/content/drive/MyDrive/FP-MBD/Hasil-FIX/hasil-customer.csv")
hasil.head()
# Out:
#   customer_id  ...                   fax
# 0       AAAAA  ...     258-816-3387x0913
# 1       AAAAB  ...         (120)353-9835
# 2       AAAAC  ...  +1-715-765-2176x1713
# 3       AAAAD  ...          126.532.7823
# 4       AAAAE  ...   (614)135-4745x14925
#
# [5 rows x 11 columns]

# %%
len(hasil)
# Out:
# 400000

# %%
print(hasil['region'][4])
# Out:
# OR

# %%
hasil['region'][:]
# Out:
# 0                Québec
# 1                  Lara
# 2         Isle of Wight
# 3         Nueva Esparta
# 4                    OR
#               ...
# 399995               CA
# 399996         Co. Cork
# 399997             Lara
# 399998               BC
# 399999               SP
# Name: region, Length: 400000, dtype: object

# %%
ov = hasil.copy()

# %%
def sql(inpt):
  if(type(inpt)==str):
    return "'{}'".format(inpt.replace("'", ""))
  else:
    return str(inpt)

# %%
ov.tail()
# Out:
#        customer_id  ...                   fax
# 399995       AWTSL  ...     196-579-4289x9623
# 399996       AWTSM  ...    (341)603-0353x7560
# 399997       AWTSN  ...            9655223591
# 399998       AWTSO  ...  +1-854-541-7306x2109
# 399999       AWTSP  ...          971-300-7804
#
# [5 rows x 11 columns]

# %%
QRY = []
jrk = ", "
for i in range(0, 400000):
  query = "INSERT INTO customers VALUES (" + sql(ov.iloc[i, 0]) + jrk + sql(ov.iloc[i, 1]) + jrk + sql(ov.iloc[i, 2])
  query += jrk + sql(ov.iloc[i, 3]) + jrk + sql(ov.iloc[i, 4]) + jrk + sql(ov.iloc[i, 5]) + jrk + sql(ov.iloc[i, 6])
  query += jrk + sql(ov.iloc[i, 7]) + jrk + sql(ov.iloc[i, 8]) + jrk + sql(ov.iloc[i, 9])
  query += jrk + sql(ov.iloc[i, 10]) + ");"
  QRY.append(query)
  #  'Vins et alcools Chevalier'==8, '59 rue de l''Abbaye', 'Reims', NULL, '51100', 'France');

# %%
len(QRY)
# Out:
# 400000

# %%
textfile = open('/content/drive/MyDrive/FP-MBD/Hasil-FIX/hasil-customer.sql', 'w')
for element in QRY:
    textfile.write(element + "\n")
textfile.close()

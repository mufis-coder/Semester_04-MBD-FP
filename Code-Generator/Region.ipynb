# %%
import pandas as pd
import numpy as np

# %%
region_df = pd.read_csv("/content/drive/MyDrive/FP-MBD/database/region.csv")
region_df
# Out:
#    region_id region_description
# 0          1            Eastern
# 1          2            Western
# 2          3           Northern
# 3          4           Southern

# %%
pip install faker
# Out:
# ...
#      |████████████████████████████████| 1.2MB 5.0MB/s
# ...

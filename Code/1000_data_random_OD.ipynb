# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel(r'/content/drive/MyDrive/FP-MBD/Hasil-FIX/order_detail_1000random.xlsx')

# %%
df.head()
# Out:
#    order_id  product_id  unit_price  quantity  discount
# 0    478657          38      201.76        59       0.0
# 1     56939          62       59.54        82       0.0
# 2    205545          71       45.91         9       0.0
# 3    271271          12      244.12        56       0.0
# 4    329191          71       24.63         7       0.0

# %%
i = 0
for x in df['product_id']:
  i += 1
  print(x, end=", ")
  if(i%100 == 0):
    print("")
# Out:
# 38, 62, 71, 12, 71, 43, 8, 2, 47, 7, 52, 19, 41, 48, 50, 39, 52, 58, 1, 36, 4, 43, 16, 59, 16, 12, 52, 17, 23, 8, 62, 62, 69, 22, 6, 29, 63, 41, 63, 38, 26, 24, 34, 17, 49, 4, 2, 62, 55, 70, 23, 28, 1, 20, 39, 24, 57, 35, 18, 66, 67, 5, 22, 12, 1, 70, 74, 50, 42, 54, 27, 21, 76, 54, 59, 36, 57, 40, 13, 14, 45, 12, 19, 59, 35, 65, 65, 54, 39, 31, 17, 22, 74, 3, 22, 21, 24, 31, 8, 6,
# 25, 27, 45, 5, 66, 38, 39, 62, 46, 24, 54, 34, 21, 65, 62, 77, 55, 69, 26, 20, 5, 61, 8, 50, 33, 72, 57, 12, 33, 14, 14, 35, 70, 60, 58, 62, 65, 52, 11, 29, 18, 50, 64, 20, 75, 18, 14, 23, 70, 63, 49, 63, 45, 31, 68, 74, 60, 71, 69, 2, 64, 31, 10, 77, 5, 29, 76, 35, 27, 67, 38, 65, 23, 74, 19, 28, 71, 47, 11, 26, 16, 27, 23, 15, 10, 75, 1, 54, 25, 37, 74, 13, 56, 52, 61, 39, 56, 45, 75, 60,
# ...
